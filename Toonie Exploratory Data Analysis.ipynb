# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\aoluw\Desktop\Github\Team-Go\Lucid blog.csv\contact_settings.csv')
print (df)
# Out:
#       id  user_id                               email  \
# 0      1       78         emmanuelezenwigbo@gmail.com
# 1      2       90                  dward009@gmail.com
# 2      3       53                   apeji93@gmail.com
# 3      4      133                 ireabueke@gmail.com
# 4      5       92                 bindas.fs@gmail.com
# 5      6      138                 detounmed@gmail.com
# 6      7      130               okakosomano@gmail.com
# 7      8      177                   mubbs24@gmail.com
# 8      9       73          charlesokoliocha@gmail.com
# 9     10      160            olaitanaderoju@gmail.com
# 10    11      123                geomaggi91@gmail.com
# 11    12      120                 iburity19@gmail.com
# 12    13      121                 chubukass@gmail.com
# 13    14      142               reeta.nzere@gmail.com
# 14    15       81               davidadigwu@gmail.com
# 15    16      150              calabarspice@gmail.com
# ...

# %%
df = pd.read_csv (r'C:\Users\aoluw\Desktop\Github\Team-Go\Lucid blog.csv\maillists.csv')
print (df)
# Out:
#     id                           email  created_at  updated_at
# 0    1               ubarab85@live.com         NaN         NaN
# 1    2            detoun4med@gmail.com         NaN         NaN
# 2    3              emmanuel@gmail.com         NaN         NaN
# 3    4              ifydechu@gmail.com         NaN         NaN
# 4    5         olaiwolaahmod@gmail.com         NaN         NaN
# 5    6        francosino5662@gmail.com         NaN         NaN
# 6    7          phemmylintry@gmail.com         NaN         NaN
# 7    8     mololuwaakintunde@gmail.com         NaN         NaN
# 8    9              idyekpoh@gmail.com         NaN         NaN
# 9   10            durabuildr@gmail.com         NaN         NaN
# 10  11     akomolafeayoyinka@gmail.com         NaN         NaN
# 11  12              ogbole12@gmail.com         NaN         NaN
# 12  13        barbaramangiri@gmail.com         NaN         NaN
# 13  14                stelroy100@gmail         NaN         NaN
# ...

# %%
df = pd.read_csv (r'C:\Users\aoluw\Desktop\Github\Team-Go\Lucid blog.csv\notifications.csv')
print (df)
# Out:
#       id  post_id  parent_comment_id  \
# 0      1      NaN                NaN
# 1      2      NaN                NaN
# 2      3      NaN                NaN
# 3      5      NaN                NaN
# 4      7    278.0                NaN
# 5      8    360.0                NaN
# 6      9    360.0                NaN
# 7     10      NaN                NaN
# 8     11    143.0                NaN
# 9     12    371.0                NaN
# 10    13      NaN                NaN
# 11    14      NaN                NaN
# 12    15    371.0                NaN
# 13    16    371.0                NaN
# 14    17      NaN                NaN
# 15    18      NaN                NaN
# 16    19      NaN                NaN
# 17    20      NaN                NaN
# 18    21      NaN                NaN
# 19    22      NaN                NaN
# 20    23      NaN                NaN
# 21    24      NaN                NaN
# 22    25      NaN                NaN
# 23    26    371.0                NaN
# ...

# %%
df = pd.read_csv (r'C:\Users\aoluw\Desktop\Github\Team-Go\Lucid blog.csv\posts.csv')
print (df)
# Out:
#        id  user_id                                              title  \
# 0       1     2077                  What i have learnt so far on HTML
# 1       2     1719                                   HTML BEGINS HERE
# 2       4     1310                            My Laziness In The Open
# 3       6     1787                                          MY TASK 2
# 4       7      167                                             Task 2
# 5       8      329                                 My Journey on HTML
# 6       9     2040                            StartNG HTML Exposition
# 7      11     1787                                          MY TASK 2
# 8      12     2040                                  StartNG HTML task
# 9      13     2040                          On StartNG Pre-Internship
# 10     15      942                                                why
# 11     16      329                                        Please note
# ...

# %%
df = pd.read_csv (r'C:\Users\aoluw\Desktop\Github\Team-Go\Lucid blog.csv\users.csv')
print (df)
# Out:
#       user_id                         name                username  \
# 0           1           Eniayomi Oluwaseyi                eniayomi
# 1           2                Elijah Okokon                 DMatrix
# 2           3                 Jeffrey Ogah               jeff.ogah
# 3           4        Oluwaseyi Oluwapelumi                  nathan
# 4           5                         PoRH                   lamar
# 5           6                 Seyi Onifade                   xyluz
# 6           7                  Mark Essien              markessien
# 7           8                   Alex Moses              ahlesswywk
# 8           9                 Edmund Ekott             26th_edmund
# 9          10                   Stefan aGz            stefanpongrz
# 10         11                 Jenni Essien             j.naiaretti
# 11         12                 Amujo Samuel             samuelamujo
# 12         13        Olatunbosun Egberinde                bosunski
# ...
